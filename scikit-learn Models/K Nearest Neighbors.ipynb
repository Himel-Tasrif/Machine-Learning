# %%
from sklearn.datasets import load_iris
d = load_iris()

# %%
dir(d)
# Out:
# ['DESCR',
#  'data',
#  'data_module',
#  'feature_names',
#  'filename',
#  'frame',
#  'target',
#  'target_names']

# %%
import pandas as pd

# %%
df = pd.DataFrame(d.data, columns = d.feature_names)
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
df['target'] = d.target
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
d.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
df['flower'] = df['target'].apply(lambda x: d.target_names[x])
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target     flower
# ...

# %%
df[df['target'] == 1].head()
# Out:
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 50                7.0               3.2                4.7               1.4
# 51                6.4               3.2                4.5               1.5
# 52                6.9               3.1                4.9               1.5
# 53                5.5               2.3                4.0               1.3
# 54                6.5               2.8                4.6               1.5
#
#     target      flower
# 50       1  versicolor
# 51       1  versicolor
# 52       1  versicolor
# 53       1  versicolor
# 54       1  versicolor

# %%
df[df['target'] == 2].head()
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 100                6.3               3.3                6.0               2.5
# 101                5.8               2.7                5.1               1.9
# 102                7.1               3.0                5.9               2.1
# 103                6.3               2.9                5.6               1.8
# 104                6.5               3.0                5.8               2.2
#
#      target     flower
# 100       2  virginica
# 101       2  virginica
# 102       2  virginica
# 103       2  virginica
# 104       2  virginica

# %%
df[df['target'] == 0].head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target  flower
# 0       0  setosa
# 1       0  setosa
# 2       0  setosa
# 3       0  setosa
# 4       0  setosa

# %%
df0 = df[:50]
df1 = df[50:100]
df2 = df[100:]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.title("Test-1", color = 'white', pad = 10)
plt.ylabel("sepal width (cm)", color = 'white')
plt.xlabel("sepal length (cm)", color = 'white')
plt.scatter(df0['sepal length (cm)'], df0['sepal width (cm)'], color = 'green', marker = '+')
plt.scatter(df1['sepal length (cm)'], df1['sepal width (cm)'], color = 'red', marker = '.')

# %%
plt.title("Test-1", color = 'white', pad = 10)
plt.ylabel("sepal width (cm)", color = 'white')
plt.xlabel("sepal length (cm)", color = 'white')
plt.scatter(df0['petal length (cm)'], df0['petal width (cm)'], color = 'green', marker = '+')
plt.scatter(df1['petal length (cm)'], df1['petal width (cm)'], color = 'red', marker = '.')

# %%
from sklearn.model_selection import train_test_split

# %%
x = df.drop(['target','flower'], axis = 'columns')
x.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
y = df.target
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: target, Length: 150, dtype: int32

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2, random_state = 2)

# %%
len(x_train)
# Out:
# 120

# %%
len(x_test)
# Out:
# 30

# %% [markdown]
# ## KNN (K Nearest Neighbor)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=20) # you can use n_neighbors=5 for 100% accuracy

# %%
knn.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=20)

# %%
knn.score(x_test, y_test)
# Out:
# 0.9666666666666667

# %%
from sklearn.metrics import confusion_matrix

# %%
y_pred = knn.predict(x_test)
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[14,  0,  0],
#        [ 0,  7,  1],
#        [ 0,  0,  8]], dtype=int64)

# %%
import seaborn as sn

# %%
plt.figure(figsize = (15,6))
sn.heatmap(cm, annot = True)
plt.xlabel("predicted", color = 'white')
plt.ylabel("Truth", color = 'white')
# Out:
# Text(114.0, 0.5, 'Truth')

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        14
#            1       1.00      0.88      0.93         8
#            2       0.89      1.00      0.94         8
#
#     accuracy                           0.97        30
#    macro avg       0.96      0.96      0.96        30
# weighted avg       0.97      0.97      0.97        30

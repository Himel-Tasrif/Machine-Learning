# %%
import pandas as pd
import mediapipe as mp
import numpy as np
import cv2

# %%
mp_drawing = mp.solutions.drawing_utils # Drawing helpers
mp_holistic = mp.solutions.holistic # Mediapipe Solutions

mp_drawing_styles = mp.solutions.drawing_styles
mp_hands = mp.solutions.hands

# %%
cap = cv2.VideoCapture(0)

# Initiate holistic model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic, \
     mp_hands.Hands(min_detection_confidence=0.5, min_tracking_confidence=0.5) as hands:
    
    
    while cap.isOpened():
        ret, frame = cap.read()

        if not ret:
            print("Unable to capture frame")
            break

        # Recolor feed
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False

        # Make detections
        results_holistic = holistic.process(image)
        results_hands = hands.process(image)

        # Recolor image back to BGR for rendering
        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

        mp_drawing.draw_landmarks(image, results_holistic.face_landmarks, mp_holistic.FACEMESH_TESSELATION,
                                  mp_drawing.DrawingSpec(color=(80, 110, 10), thickness=1, circle_radius=1),
                                  mp_drawing.DrawingSpec(color=(80, 256, 121), thickness=1, circle_radius=1))

        # Draw pose landmarks
        mp_drawing.draw_landmarks(image, results_holistic.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                                  mp_drawing.DrawingSpec(color=(245, 117, 66), thickness=2, circle_radius=4),
                                  mp_drawing.DrawingSpec(color=(245, 66, 230), thickness=2, circle_radius=2))

        # Draw hand landmarks
        if results_hands.multi_hand_landmarks:
            for hand_landmarks in results_hands.multi_hand_landmarks:
                mp_drawing.draw_landmarks(image, hand_landmarks, mp_hands.HAND_CONNECTIONS,
                                          mp_drawing_styles.get_default_hand_landmarks_style(),
                                          mp_drawing_styles.get_default_hand_connections_style())
                
        
        cv2.imshow('Webcam Feed', image)

        # Break the loop if 'q' is pressed
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

# Release the webcam and close all windows
cap.release()
cv2.destroyAllWindows()

# %%
print(hand_landmarks.landmark)
len(hand_landmarks.landmark)
# Out:
# [x: 0.12649976
# y: 0.9388042
# z: 5.6921454e-07
# , x: 0.19294038
# y: 0.92461133
# z: -0.03972185
# , x: 0.252006
# y: 0.8713629
# z: -0.058481056
# , x: 0.26838687
# y: 0.8060311
# z: -0.075369075
# , x: 0.2616213
# y: 0.74148875
# z: -0.09199355
# , x: 0.24663799
# y: 0.6876868
# z: -0.028268332
# , x: 0.28247505
# y: 0.596673
# z: -0.054442156
# , x: 0.30909997
# y: 0.55443096
# z: -0.076498315
# , x: 0.33118182
# y: 0.53472686
# z: -0.09034735
# , x: 0.19530816
# y: 0.6626181
# z: -0.028660009
# , x: 0.21068728
# y: 0.5517471
# z: -0.0517101
# , x: 0.22562379
# y: 0.51379573
# z: -0.07066996
# , x: 0.23845017
# y: 0.51759964
# z: -0.082049996
# , x: 0.14145358
# y: 0.67257875
# z: -0.03419471
# , x: 0.14663762
# y: 0.5590998
# z: -0.06397124
# , x: 0.1555062
# y: 0.5441067
# z: -0.07759509
# , x: 0.16585667
# y: 0.56440055
# z: -0.08290161
# , x: 0.08428869
# y: 0.71114194
# z: -0.043207258
# , x: 0.07953047
# y: 0.63137096
# z: -0.07688906
# , x: 0.08533119
# y: 0.6536871
# z: -0.083854735
# , x: 0.09153631
# y: 0.7059896
# z: -0.082430705
# ]
# 21

# %%
print(results_holistic.pose_landmarks.landmark)
len(results_holistic.pose_landmarks.landmark)
# Out:
# [x: 0.59619147
# y: 0.58788645
# z: -1.2066256
# visibility: 0.9999647
# , x: 0.62201846
# y: 0.52808017
# z: -1.1344244
# visibility: 0.999946
# , x: 0.63603693
# y: 0.5295229
# z: -1.1341771
# visibility: 0.9999087
# , x: 0.6508301
# y: 0.53176445
# z: -1.133898
# visibility: 0.99990773
# , x: 0.5659996
# y: 0.52519995
# z: -1.1286436
# visibility: 0.99995863
# , x: 0.5440271
# y: 0.5243972
# z: -1.1284297
# visibility: 0.9999526
# , x: 0.52557456
# y: 0.5252441
# z: -1.1286509
# visibility: 0.9999705
# , x: 0.6694091
# y: 0.5526811
# z: -0.6824423
# visibility: 0.9998908
# , x: 0.50482506
# y: 0.5505353
# z: -0.65426576
# visibility: 0.9999762
# , x: 0.6257225
# y: 0.65036446
# z: -1.0440493
# visibility: 0.9999473
# , x: 0.5583488
# y: 0.642366
# z: -1.032514
# visibility: 0.99997026
# , x: 0.78612125
# y: 0.85923404
# z: -0.37229893
# visibility: 0.99780166
# , x: 0.3924741
# y: 0.8563225
# z: -0.43057808
# visibility: 0.9987822
# , x: 0.9290613
# y: 1.248282
# z: -0.30140448
# visibility: 0.8145458
# , x: 0.14948538
# y: 1.0773418
# z: -0.96786994
# visibility: 0.9960291
# , x: 0.9237038
# y: 1.45938
# z: -0.49511266
# visibility: 0.7819836
# , x: 0.28232935
# y: 0.69338727
# z: -1.7087727
# visibility: 0.9947904
# , x: 0.95045185
# y: 1.5314645
# z: -0.5588694
# visibility: 0.73910826
# , x: 0.30576605
# y: 0.5301901
# z: -1.8789318
# visibility: 0.9827168
# , x: 0.91395485
# y: 1.5082345
# z: -0.5777559
# visibility: 0.760442
# , x: 0.341646
# y: 0.5313157
# z: -1.7711685
# visibility: 0.98428404
# , x: 0.8914827
# y: 1.4870956
# z: -0.521756
# visibility: 0.74481785
# , x: 0.3572684
# y: 0.58779424
# z: -1.6905676
# visibility: 0.9791245
# , x: 0.69749564
# y: 1.56736
# z: -0.11836854
# visibility: 0.002202609
# , x: 0.41449112
# y: 1.5536023
# z: 0.12218998
# visibility: 0.0022665937
# , x: 0.6880434
# y: 2.1925604
# z: -0.26120198
# visibility: 0.0059389137
# , x: 0.44399303
# y: 2.1942296
# z: 0.1639193
# visibility: 0.0018795517
# , x: 0.682665
# y: 2.754047
# z: 0.3079719
# visibility: 0.0001896634
# , x: 0.4450354
# y: 2.7443933
# z: 0.55931646
# visibility: 7.314179e-05
# , x: 0.69070834
# y: 2.833716
# z: 0.32621637
# visibility: 7.707114e-05
# , x: 0.43786293
# y: 2.8199773
# z: 0.5875548
# visibility: 8.855428e-05
# , x: 0.63726836
# y: 2.9176378
# z: -0.31191966
# visibility: 0.00029512227
# , x: 0.4614447
# y: 2.922808
# z: -0.081399694
# visibility: 0.00035407225
# ]
# 33

# %%
print(results_holistic.face_landmarks.landmark[0])
len(results_holistic.face_landmarks.landmark)
# Out:
# x: 0.600447
# y: 0.6408635
# z: -0.020413904
# 468

# %%
import csv
import os

# %%
num_coords = len(results_holistic.face_landmarks.landmark) + len(results_holistic.pose_landmarks.landmark) + len(hand_landmarks.landmark)
num_coords
# Out:
# 522

# %%
landmarks = ['class']
for val in range(1, num_coords+1):
    landmarks += ['x{}'.format(val), 'y{}'.format(val), 'z{}'.format(val), 'v{}'.format(val)]

# %%
landmarks[-1]
# Out:
# 'v522'

# %%
landmarks[-2]
# Out:
# 'z522'

# %%
with open('coords.csv', mode='w', newline='') as f:
    csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
    csv_writer.writerow(landmarks)

# %%
class_name = "No_Salute"

# %%
cap = cv2.VideoCapture(0)

# Initiate holistic model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic, \
     mp_hands.Hands(min_detection_confidence=0.5, min_tracking_confidence=0.5) as hands:
    
    
    while cap.isOpened():
        ret, frame = cap.read()

        if not ret:
            print("Unable to capture frame")
            break

        # Recolor feed
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False

        # Make detections
        results_holistic = holistic.process(image)
        results_hands = hands.process(image)

        # Recolor image back to BGR for rendering
        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

        mp_drawing.draw_landmarks(image, results_holistic.face_landmarks, mp_holistic.FACEMESH_TESSELATION,
                                  mp_drawing.DrawingSpec(color=(80, 110, 10), thickness=1, circle_radius=1),
                                  mp_drawing.DrawingSpec(color=(80, 256, 121), thickness=1, circle_radius=1))

        # Draw pose landmarks
        mp_drawing.draw_landmarks(image, results_holistic.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                                  mp_drawing.DrawingSpec(color=(245, 117, 66), thickness=2, circle_radius=4),
                                  mp_drawing.DrawingSpec(color=(245, 66, 230), thickness=2, circle_radius=2))

        # Draw hand landmarks
        if results_hands.multi_hand_landmarks:
            for hand_landmarks in results_hands.multi_hand_landmarks:
                mp_drawing.draw_landmarks(image, hand_landmarks, mp_hands.HAND_CONNECTIONS,
                                          mp_drawing_styles.get_default_hand_landmarks_style(),
                                          mp_drawing_styles.get_default_hand_connections_style())
                

        try:
            # Extract pose landmarks
            pose_landmarks = results_holistic.pose_landmarks.landmark
            pose_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in pose_landmarks]).flatten())

            # Extract face landmarks
            face_landmarks = results_holistic.face_landmarks.landmark
            face_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in face_landmarks]).flatten())

            # Extract hand landmarks
            hand_landmarks = []
            if results_hands.multi_hand_landmarks:
                for hand_landmark in results_hands.multi_hand_landmarks:
                    hand_landmarks.extend(list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in hand_landmark.landmark]).flatten()))

            # Concatenate rows
            row = pose_row + face_row + hand_landmarks

            # Append class name
            row.insert(0, class_name)

            with open('coords.csv', mode='a', newline='') as f:
                csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
                csv_writer.writerow(row)

        except Exception as e:
            print(f"Error: {e}")
                
        
        cv2.imshow('Webcam Feed', image)

        # Break the loop if 'q' is pressed
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

# Release the webcam and close all windows
cap.release()
cv2.destroyAllWindows()

# %%
pose_landmarks = results_holistic.pose_landmarks.landmark
pose_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in pose_landmarks]).flatten())
len(pose_row)
# Out:
# 132

# %%
face_landmarks = results_holistic.face_landmarks.landmark
face_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in face_landmarks]).flatten())
len(face_row)
# Out:
# 1872

# %%
pose = hand_landmarks.landmark
himel = list(np.array([[landmark.x, landmark.y, landmark.z] for landmark in pose]).flatten())
len(himel)
# Out:
# 63

# %%
row = pose_row + face_row + himel
len(row)
# Out:
# 1566

# %%
rani = []
if results_hands.multi_hand_landmarks:
    for hand_landmark in results_hands.multi_hand_landmarks:
        rani.extend(list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in hand_landmark.landmark]).flatten()))

# %%
len(rani)
# Out:
# 84

# %%
row = pose_row + face_row + rani
row.insert(0, class_name)
len(row)
# Out:
# 2089

# %%
1+ 522*4
# Out:
# 2089

# %%
row
# Out:
# ['Best_Salute',
#  0.5248900651931763,
#  0.6861022114753723,
#  -0.8715718388557434,
#  0.9999690651893616,
#  0.5485844016075134,
#  0.6235541701316833,
#  -0.8168802261352539,
#  0.9999378323554993,
#  0.5636047720909119,
#  0.6228765249252319,
#  -0.8166862726211548,
#  0.9999138116836548,
#  0.5775024890899658,
#  0.623230516910553,
#  -0.8166059255599976,
#  0.9999238848686218,
#  0.49608150124549866,
#  0.62485671043396,
#  -0.803083062171936,
#  0.9999428987503052,
#  0.47791463136672974,
#  0.6256049275398254,
#  -0.8023481369018555,
#  0.9999279379844666,
#  0.46233662962913513,
#  0.6278321146965027,
#  -0.8023092150688171,
#  0.9999498724937439,
#  0.6021479964256287,
#  0.6423604488372803,
#  -0.4475756585597992,
#  0.9999209642410278,
#  0.44660526514053345,
#  0.6528916954994202,
#  -0.37301889061927795,
#  0.9999478459358215,
#  0.5558627843856812,
#  0.7452483773231506,
#  -0.7432203888893127,
#  0.9999363422393799,
#  0.4940907061100006,
#  0.7501015067100525,
#  -0.7213137745857239,
#  0.9999496340751648,
#  0.7354593873023987,
#  0.9315134286880493,
#  -0.2578497529029846,
#  0.9983928203582764,
#  0.3414626717567444,
#  0.9463508129119873,
#  -0.19809933006763458,
#  0.9991251826286316,
#  0.8530498743057251,
#  1.3084328174591064,
#  -0.324571430683136,
#  0.5761389136314392,
#  0.13339850306510925,
#  1.2538182735443115,
#  -0.813859760761261,
#  0.8985995054244995,
#  0.8767222166061401,
#  1.565507411956787,
#  -0.5928581953048706,
#  0.6235613226890564,
#  0.14577044546604156,
#  0.9227586984634399,
#  -1.7811708450317383,
#  0.9187642931938171,
#  0.9150521159172058,
#  1.6547497510910034,
#  -0.6779977083206177,
#  0.6229963302612305,
#  0.15860384702682495,
#  0.7782648205757141,
#  -1.9717642068862915,
#  0.9035012125968933,
#  0.8642929196357727,
#  1.643975853919983,
#  -0.7042505741119385,
#  0.6538147330284119,
#  0.21333596110343933,
#  0.7238416075706482,
#  -1.9269237518310547,
#  0.9149301648139954,
#  0.8380085825920105,
#  1.6163079738616943,
#  -0.6253942251205444,
#  0.6581850051879883,
#  0.2350541651248932,
#  0.7918475866317749,
#  -1.7973291873931885,
#  0.9109593033790588,
#  0.6749982833862305,
#  1.637381911277771,
# 3160 -0.015997     0  0.353696  0.159016 -0.018180     0
# 3161 -0.018919     0  0.352561  0.158218 -0.021282     0
# 3162 -0.018830     0  0.351120  0.157770 -0.020962     0
# 3163 -0.019695     0  0.351710  0.156247 -0.022277     0
# 3164 -0.020921     0  0.350250  0.153432 -0.023482     0
#
# [3165 rows x 2089 columns]

# %%
import pandas as pd
columns_with_null = df.isnull().any()

print("Columns with null values:")
print(columns_with_null)
# Out:
# Columns with null values:
# class    False
# x1       False
# y1       False
# z1       False
# v1       False
#          ...
# v521     False
# x522     False
# y522     False
# z522     False
# v522     False
# Length: 2089, dtype: bool

# %%
x = df.drop('class', axis=1) # features
y = df['class']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
x_train.shape
# Out:
# (2532, 2088)

# %%
y_train.shape
# Out:
# (2532,)

# %%
x_test.shape
# Out:
# (633, 2088)

# %%
y_test.shape
# Out:
# (633,)

# %%
x_train.head(5)
# Out:
#             x1        y1        z1        v1        x2        y2        z2  \
# 2638  0.531803  0.464234 -0.798235  0.999905  0.558240  0.404976 -0.729782
# 1097  0.505529  0.475348 -0.568654  0.999998  0.528345  0.417786 -0.512625
# 682   0.530335  0.473138 -0.840069  0.999806  0.559232  0.419146 -0.764679
# 1052  0.528199  0.447211 -0.551164  0.999988  0.549571  0.386600 -0.489514
# 637   0.549446  0.479786 -0.830921  0.999815  0.570313  0.427453 -0.760443
#
#             v2        x3        y3  ...      z520  v520      x521      y521  \
# 2638  0.999792  0.575465  0.405889  ... -0.014626     0  0.289095  0.316897
# 1097  0.999997  0.544051  0.416821  ... -0.046249     0  0.645977  0.497869
# 682   0.999686  0.572530  0.422468  ... -0.007241     0  0.388060  0.369747
# 1052  0.999976  0.563218  0.386404  ... -0.097401     0  1.075024  0.604915
# 637   0.999686  0.582890  0.430487  ... -0.008377     0  0.401744  0.357755
#
#           z521  v521      x522      y522      z522  v522
# 2638 -0.018948     0  0.305281  0.293457 -0.021472     0
# 1097 -0.047222     0  0.627275  0.472944 -0.048262     0
# 682  -0.008317     0  0.404339  0.366216 -0.008684     0
# 1052 -0.109998     0  1.094804  0.561124 -0.118117     0
# 637  -0.010197     0  0.418984  0.356302 -0.010559     0
#
# [5 rows x 2088 columns]

# %%
y_train.head(5)
# Out:
# 2638      No_Salute
# 1097     Wrong_Hand
# 682     Best_Salute
# 1052     Wrong_Hand
# 637     Best_Salute
# Name: class, dtype: object

# %%
from sklearn.pipeline import make_pipeline 
from sklearn.preprocessing import StandardScaler 

from sklearn.linear_model import LogisticRegression, RidgeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

# %%
pipelines = {
    'lr':make_pipeline(StandardScaler(), LogisticRegression()),
    'rc':make_pipeline(StandardScaler(), RidgeClassifier()),
    'rf':make_pipeline(StandardScaler(), RandomForestClassifier()),
    'gb':make_pipeline(StandardScaler(), GradientBoostingClassifier()),
}

# %%
pipelines.keys()
# Out:
# dict_keys(['lr', 'rc', 'rf', 'gb'])

# %%
list(pipelines.values())
# Out:
# [Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression', LogisticRegression())]),
#  Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('ridgeclassifier', RidgeClassifier())]),
#  Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier', RandomForestClassifier())]),
#  Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('gradientboostingclassifier', GradientBoostingClassifier())])]

# %%
fit_models = {}
for algo, pipeline in pipelines.items():
    model = pipeline.fit(x_train, y_train)
    fit_models[algo] = model
# Out:
# c:\Users\DCL\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
fit_models['rc'].predict(x_test)
# Out:
# array(['No_Salute', 'Best_Salute', 'Best_Salute', 'Best_Salute',
#        'Wrong_Hand', 'Best_Salute', 'Best_Salute', 'No_Salute',
#        'Best_Salute', 'Wrong_Hand', 'No_Salute', 'No_Salute',
#        'Wrong_Hand', 'No_Salute', 'No_Salute', 'No_Salute', 'No_Salute',
#        'No_Salute', 'Wrong_Hand', 'Wrong_Hand', 'No_Salute', 'Wrong_Hand',
#        'Best_Salute', 'Best_Salute', 'Best_Salute', 'No_Salute',
#        'Wrong_Hand', 'Best_Salute', 'Wrong_Hand', 'Best_Salute',
#        'Best_Salute', 'No_Salute', 'Wrong_Hand', 'Wrong_Hand',
#        'No_Salute', 'Wrong_Hand', 'No_Salute', 'Wrong_Hand',
#        'Best_Salute', 'Best_Salute', 'Wrong_Hand', 'Best_Salute',
#        'Best_Salute', 'No_Salute', 'No_Salute', 'Best_Salute',
#        'Best_Salute', 'No_Salute', 'Best_Salute', 'No_Salute',
#        'No_Salute', 'No_Salute', 'Wrong_Hand', 'No_Salute', 'No_Salute',
#        'Wrong_Hand', 'No_Salute', 'Wrong_Hand', 'No_Salute', 'Wrong_Hand',
#        'No_Salute', 'No_Salute', 'No_Salute', 'Best_Salute',
#        'Best_Salute', 'No_Salute', 'Best_Salute', 'No_Salute',
#        'Wrong_Hand', 'No_Salute', 'Wrong_Hand', 'No_Salute',
#        'Best_Salute', 'No_Salute', 'Best_Salute', 'Best_Salute',
#        'Wrong_Hand', 'Best_Salute', 'No_Salute', 'No_Salute',
#        'Wrong_Hand', 'Best_Salute', 'Best_Salute', 'No_Salute',
#        'Best_Salute', 'Best_Salute', 'Best_Salute', 'Wrong_Hand',
#        'No_Salute', 'Wrong_Hand', 'Wrong_Hand', 'No_Salute',
#        'Best_Salute', 'No_Salute', 'No_Salute', 'Wrong_Hand', 'No_Salute',
#        'Best_Salute', 'Best_Salute', 'No_Salute', 'No_Salute',
#        'Best_Salute', 'Best_Salute', 'Best_Salute', 'Wrong_Hand',
#        'No_Salute', 'Wrong_Hand', 'Best_Salute', 'No_Salute', 'No_Salute',
#        'Wrong_Hand', 'No_Salute', 'Best_Salute', 'No_Salute',
#        'Wrong_Hand', 'No_Salute', 'Best_Salute', 'No_Salute', 'No_Salute',
#        'Best_Salute', 'No_Salute', 'No_Salute', 'Best_Salute',
#        'Best_Salute', 'Best_Salute', 'Wrong_Hand', 'Wrong_Hand',
#        'Best_Salute', 'Best_Salute', 'Best_Salute', 'Best_Salute',
#        'Wrong_Hand', 'Best_Salute', 'Best_Salute', 'Wrong_Hand',
#        'Wrong_Hand', 'No_Salute', 'No_Salute', 'Wrong_Hand', 'Wrong_Hand',
#        'Wrong_Hand', 'No_Salute', 'Wrong_Hand', 'Best_Salute',
#        'No_Salute', 'No_Salute', 'No_Salute', 'No_Salute', 'Wrong_Hand',
#        'Best_Salute', 'Best_Salute', 'Best_Salute', 'Best_Salute',
#        'Wrong_Hand', 'Wrong_Hand', 'No_Salute', 'Wrong_Hand', 'No_Salute',
#        'Wrong_Hand', 'Best_Salute', 'No_Salute', 'Best_Salute',
#        'Best_Salute', 'Best_Salute', 'Best_Salute', 'No_Salute',
#        'Best_Salute', 'Wrong_Hand', 'Best_Salute', 'No_Salute',
#        'Best_Salute', 'No_Salute', 'Wrong_Hand', 'Wrong_Hand',
#        'Best_Salute', 'Best_Salute', 'Best_Salute', 'Wrong_Hand',
#        'No_Salute', 'Wrong_Hand', 'Best_Salute', 'Best_Salute',
#        'Best_Salute', 'Best_Salute', 'No_Salute', 'Wrong_Hand',
#        'Best_Salute', 'Wrong_Hand', 'Best_Salute', 'No_Salute',
#        'Wrong_Hand', 'Wrong_Hand', 'No_Salute', 'No_Salute', 'No_Salute',
#        'Wrong_Hand', 'Wrong_Hand', 'Wrong_Hand', 'Best_Salute',
#        'Best_Salute', 'No_Salute', 'No_Salute', 'Best_Salute',
#        'Best_Salute', 'No_Salute', 'Best_Salute', 'Best_Salute',
#        'Wrong_Hand', 'Best_Salute', 'No_Salute', 'Best_Salute',
#        'Wrong_Hand', 'Best_Salute', 'Best_Salute', 'Wrong_Hand',
#        'Wrong_Hand', 'Best_Salute', 'No_Salute', 'No_Salute', 'No_Salute',
#        'Wrong_Hand', 'No_Salute', 'Best_Salute', 'Best_Salute',
#        'No_Salute', 'Best_Salute', 'Best_Salute', 'Wrong_Hand',
#        'Best_Salute', 'No_Salute', 'Best_Salute', 'Best_Salute',
#        'No_Salute', 'Wrong_Hand', 'Wrong_Hand', 'No_Salute', 'No_Salute',
#        'Wrong_Hand', 'Best_Salute', 'Best_Salute', 'Best_Salute',
#        'Wrong_Hand', 'No_Salute', 'Best_Salute', 'No_Salute', 'No_Salute',
#        'No_Salute', 'No_Salute', 'Best_Salute', 'Best_Salute',
#        'Wrong_Hand', 'No_Salute', 'No_Salute', 'No_Salute', 'Best_Salute',
#        'Best_Salute', 'Wrong_Hand', 'Best_Salute', 'Best_Salute',
#        'Best_Salute', 'No_Salute', 'Best_Salute', 'Best_Salute',
#        'No_Salute', 'Wrong_Hand', 'No_Salute', 'No_Salute', 'Best_Salute',
#        'Wrong_Hand', 'No_Salute', 'No_Salute', 'Wrong_Hand', 'No_Salute',
#        'Wrong_Hand', 'Wrong_Hand', 'No_Salute', 'No_Salute', 'Wrong_Hand',
#        'Best_Salute', 'Wrong_Hand', 'Best_Salute', 'Wrong_Hand',
#        'Best_Salute', 'Wrong_Hand', 'No_Salute', 'No_Salute',
#        'Wrong_Hand', 'No_Salute', 'Wrong_Hand', 'Best_Salute',
#        'No_Salute', 'Wrong_Hand', 'Wrong_Hand', 'Wrong_Hand', 'No_Salute',
#        'Wrong_Hand', 'Wrong_Hand', 'No_Salute', 'No_Salute', 'Wrong_Hand',
#        'No_Salute', 'No_Salute', 'Best_Salute', 'No_Salute', 'No_Salute',
#        'Wrong_Hand', 'Best_Salute', 'Wrong_Hand', 'Best_Salute',
#        'Best_Salute', 'Best_Salute', 'No_Salute', 'Wrong_Hand',
#        'No_Salute', 'No_Salute', 'No_Salute', 'No_Salute', 'No_Salute',
#        'Wrong_Hand', 'Wrong_Hand', 'Best_Salute', 'Best_Salute',
#        'No_Salute', 'No_Salute', 'No_Salute', 'Wrong_Hand', 'Wrong_Hand',
#        'Wrong_Hand', 'No_Salute', 'No_Salute', 'Wrong_Hand', 'No_Salute',
#        'No_Salute', 'No_Salute', 'Best_Salute', 'Best_Salute',
#        'No_Salute', 'Wrong_Hand', 'Best_Salute', 'Wrong_Hand',
#        'Best_Salute', 'No_Salute', 'No_Salute', 'No_Salute',
#        'Best_Salute', 'No_Salute', 'No_Salute', 'Best_Salute',
#        'Best_Salute', 'Best_Salute', 'Best_Salute', 'Best_Salute',
#        'No_Salute', 'No_Salute', 'Best_Salute', 'Best_Salute',
#        'No_Salute', 'Best_Salute', 'Wrong_Hand', 'Wrong_Hand',
#        'No_Salute', 'No_Salute', 'Wrong_Hand', 'Wrong_Hand', 'Wrong_Hand',
#        'Wrong_Hand', 'Wrong_Hand', 'Wrong_Hand', 'Best_Salute',
#        'No_Salute', 'Wrong_Hand', 'Wrong_Hand', 'No_Salute', 'No_Salute',
#        'No_Salute', 'Wrong_Hand', 'Wrong_Hand', 'Best_Salute',
#        'No_Salute', 'Wrong_Hand', 'No_Salute', 'Best_Salute',
#        'Wrong_Hand', 'Wrong_Hand', 'No_Salute', 'Wrong_Hand', 'No_Salute',
#        'No_Salute', 'Best_Salute', 'No_Salute', 'Wrong_Hand', 'No_Salute',
#        'Wrong_Hand', 'Wrong_Hand', 'Wrong_Hand', 'Best_Salute',
#        'Best_Salute', 'No_Salute', 'Best_Salute', 'Best_Salute',
#        'Wrong_Hand', 'Wrong_Hand', 'Wrong_Hand', 'No_Salute',
#        'Best_Salute', 'Wrong_Hand', 'Best_Salute', 'No_Salute',
#        'Best_Salute', 'Wrong_Hand', 'No_Salute', 'Wrong_Hand',
#        'No_Salute', 'Best_Salute', 'Best_Salute', 'Wrong_Hand',
#        'Wrong_Hand', 'No_Salute', 'No_Salute', 'Best_Salute',
#        'Best_Salute', 'Best_Salute', 'No_Salute', 'No_Salute',
#        'Wrong_Hand', 'No_Salute', 'Wrong_Hand', 'No_Salute', 'Wrong_Hand',
#        'Best_Salute', 'Wrong_Hand', 'Wrong_Hand', 'Best_Salute',
#        'Best_Salute', 'Wrong_Hand', 'Wrong_Hand', 'Best_Salute',
#        'Best_Salute', 'Wrong_Hand', 'Wrong_Hand', 'Wrong_Hand',
#        'Wrong_Hand', 'Wrong_Hand', 'Wrong_Hand', 'No_Salute',
#        'Wrong_Hand', 'No_Salute', 'Wrong_Hand', 'No_Salute', 'No_Salute',
#        'Best_Salute', 'Wrong_Hand', 'Best_Salute', 'Wrong_Hand',
#        'No_Salute', 'Best_Salute', 'No_Salute', 'Best_Salute',
#        'Best_Salute', 'No_Salute', 'Wrong_Hand', 'Best_Salute',
#        'No_Salute', 'Best_Salute', 'Wrong_Hand', 'Best_Salute',
#        'Wrong_Hand', 'Best_Salute', 'Wrong_Hand', 'Best_Salute',
#        'Wrong_Hand', 'Best_Salute', 'Wrong_Hand', 'Best_Salute',
#        'Wrong_Hand', 'Best_Salute', 'No_Salute', 'Best_Salute',
#        'Best_Salute', 'Wrong_Hand', 'No_Salute', 'Wrong_Hand',
#        'Wrong_Hand', 'Wrong_Hand', 'No_Salute', 'Best_Salute',
#        'Wrong_Hand', 'No_Salute', 'No_Salute', 'Best_Salute',
#        'Best_Salute', 'No_Salute', 'Wrong_Hand', 'Best_Salute',
#        'No_Salute', 'No_Salute', 'Best_Salute', 'No_Salute', 'Wrong_Hand',
#        'Wrong_Hand', 'Wrong_Hand', 'Wrong_Hand', 'Best_Salute',
#        'Best_Salute', 'No_Salute', 'Wrong_Hand', 'Wrong_Hand',
#        'No_Salute', 'Best_Salute', 'No_Salute', 'No_Salute', 'No_Salute',
#        'Wrong_Hand', 'Wrong_Hand', 'Best_Salute', 'No_Salute',
#        'Wrong_Hand', 'Best_Salute', 'No_Salute', 'No_Salute', 'No_Salute',
#        'No_Salute', 'Wrong_Hand', 'No_Salute', 'Wrong_Hand', 'No_Salute',
#        'Wrong_Hand', 'No_Salute', 'Wrong_Hand', 'Wrong_Hand',
#        'Wrong_Hand', 'Wrong_Hand', 'No_Salute', 'Best_Salute',
#        'No_Salute', 'No_Salute', 'Best_Salute', 'Best_Salute',
#        'No_Salute', 'Wrong_Hand', 'No_Salute', 'Best_Salute',
#        'Best_Salute', 'Best_Salute', 'No_Salute', 'Wrong_Hand',
#        'Best_Salute', 'No_Salute', 'Wrong_Hand', 'Wrong_Hand',
#        'No_Salute', 'No_Salute', 'Best_Salute', 'Wrong_Hand', 'No_Salute',
#        'No_Salute', 'Wrong_Hand', 'Best_Salute', 'No_Salute',
#        'Best_Salute', 'Best_Salute', 'Best_Salute', 'Best_Salute',
#        'Best_Salute', 'No_Salute', 'No_Salute', 'Best_Salute',
#        'Best_Salute', 'No_Salute', 'No_Salute', 'Best_Salute',
#        'No_Salute', 'Wrong_Hand', 'Wrong_Hand', 'No_Salute',
#        'Best_Salute', 'Best_Salute', 'Best_Salute', 'Wrong_Hand',
#        'Best_Salute', 'Wrong_Hand', 'Best_Salute', 'No_Salute',
#        'Best_Salute', 'Wrong_Hand', 'No_Salute', 'No_Salute',
#        'Best_Salute', 'No_Salute', 'No_Salute', 'Best_Salute',
#        'Wrong_Hand', 'No_Salute', 'Best_Salute', 'Best_Salute',
#        'Best_Salute', 'Wrong_Hand', 'No_Salute', 'Best_Salute',
#        'Best_Salute', 'No_Salute', 'No_Salute', 'No_Salute', 'No_Salute',
#        'Best_Salute', 'No_Salute', 'Best_Salute', 'No_Salute',
#        'Best_Salute', 'Wrong_Hand', 'No_Salute', 'No_Salute',
#        'Best_Salute', 'Wrong_Hand', 'Best_Salute', 'Best_Salute',
#        'Best_Salute', 'No_Salute', 'No_Salute', 'Wrong_Hand',
#        'Best_Salute', 'Best_Salute', 'Wrong_Hand', 'Best_Salute',
#        'No_Salute', 'No_Salute', 'No_Salute', 'Best_Salute', 'No_Salute',
#        'No_Salute', 'No_Salute', 'No_Salute', 'No_Salute'], dtype='<U11')

# %%
from sklearn.metrics import accuracy_score # Accuracy metrics 
import pickle

# %%
for algo, model in fit_models.items():
    yhat = model.predict(x_test)
    print(algo, accuracy_score(y_test, yhat))
# Out:
# lr 1.0
# rc 1.0
# rf 1.0
# gb 1.0

# %%
fit_models['rf'].predict(x_test[:10])
# Out:
# array(['No_Salute', 'Best_Salute', 'Best_Salute', 'Best_Salute',
#        'Wrong_Hand', 'Best_Salute', 'Best_Salute', 'No_Salute',
#        'Best_Salute', 'Wrong_Hand'], dtype=object)

# %%
y_test[:10]
# Out:
# 2618      No_Salute
# 346     Best_Salute
# 170     Best_Salute
# 354     Best_Salute
# 1558     Wrong_Hand
# 761     Best_Salute
# 408     Best_Salute
# 2720      No_Salute
# 557     Best_Salute
# 1037     Wrong_Hand
# Name: class, dtype: object

# %%
#fit_models['rf'].predict(row)

# %%
with open('body_language.pkl', 'wb') as f:
    pickle.dump(fit_models['rf'], f)

# %%
import pickle

# %%
with open('body_language.pkl', 'rb') as f:
    model = pickle.load(f)

# %%
model
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('randomforestclassifier', RandomForestClassifier())])

# %%
model.predict(x_test[:5])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 model.predict(x_test[:5])
#
# NameError: name 'x_test' is not defined

# %%
import warnings
warnings.filterwarnings("ignore", message="X does not have valid feature names")

cap = cv2.VideoCapture(0)

# Initiate holistic model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic, \
     mp_hands.Hands(min_detection_confidence=0.5, min_tracking_confidence=0.5) as hands:
    
    
    while cap.isOpened():
        ret, frame = cap.read()

        if not ret:
            print("Unable to capture frame")
            break

        # Recolor feed
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False

        # Make detections
        results_holistic = holistic.process(image)
        results_hands = hands.process(image)

        # Recolor image back to BGR for rendering
        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

        mp_drawing.draw_landmarks(image, results_holistic.face_landmarks, mp_holistic.FACEMESH_TESSELATION,
                                  mp_drawing.DrawingSpec(color=(80, 110, 10), thickness=1, circle_radius=1),
                                  mp_drawing.DrawingSpec(color=(80, 256, 121), thickness=1, circle_radius=1))

        # Draw pose landmarks
        mp_drawing.draw_landmarks(image, results_holistic.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                                  mp_drawing.DrawingSpec(color=(245, 117, 66), thickness=2, circle_radius=4),
                                  mp_drawing.DrawingSpec(color=(245, 66, 230), thickness=2, circle_radius=2))

        # Draw hand landmarks
        if results_hands.multi_hand_landmarks:
            for hand_landmarks in results_hands.multi_hand_landmarks:
                mp_drawing.draw_landmarks(image, hand_landmarks, mp_hands.HAND_CONNECTIONS,
                                          mp_drawing_styles.get_default_hand_landmarks_style(),
                                          mp_drawing_styles.get_default_hand_connections_style())
                

        try:
            # Extract pose landmarks
            pose_landmarks = results_holistic.pose_landmarks.landmark
            pose_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in pose_landmarks]).flatten())

            # Extract face landmarks
            face_landmarks = results_holistic.face_landmarks.landmark
            face_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in face_landmarks]).flatten())

            # Extract hand landmarks
            hand_landmarks = []
            if results_hands.multi_hand_landmarks:
                for hand_landmark in results_hands.multi_hand_landmarks:
                    hand_landmarks.extend(list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in hand_landmark.landmark]).flatten()))

            # Concatenate rows
            row = pose_row + face_row + hand_landmarks

            # Append class name
            # row.insert(0, class_name)

            # with open('coords.csv', mode='a', newline='') as f:
            #     csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
            #     csv_writer.writerow(row)

            X = pd.DataFrame([row])
            body_language_class = model.predict(X)[0]
            body_language_prob = model.predict_proba(X)[0]
            print(body_language_class, body_language_prob)

        except Exception as e:
            print(f"Error: {e}")
                
        
        cv2.imshow('Webcam Feed', image)

        # Break the loop if 'q' is pressed
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

# Release the webcam and close all windows
cap.release()
cv2.destroyAllWindows()
# Out:
# Error: name 'model' is not defined
# Error: name 'model' is not defined
# Error: name 'model' is not defined
# Error: name 'model' is not defined
# Error: name 'model' is not defined
# Error: name 'model' is not defined
# Error: name 'model' is not defined
# Error: name 'model' is not defined
# Error: name 'model' is not defined
# Error: name 'model' is not defined
# Error: name 'model' is not defined
# Error: name 'model' is not defined
# Error: name 'model' is not defined
# Error: name 'model' is not defined
# Error: name 'model' is not defined
# Error: name 'model' is not defined
# Error: name 'model' is not defined
# Error: name 'model' is not defined
# Error: name 'model' is not defined
# Error: name 'model' is not defined
# Error: name 'model' is not defined
# Error: name 'model' is not defined
# Error: name 'model' is not defined
# Error: name 'model' is not defined
# Error: name 'model' is not defined
# Error: name 'model' is not defined
# Error: name 'model' is not defined
# Error: name 'model' is not defined
# Error: name 'model' is not defined
# Error: name 'model' is not defined
# Error: name 'model' is not defined
# Error: name 'model' is not defined
# Error: name 'model' is not defined
# Error: name 'model' is not defined
# Error: name 'model' is not defined
# Error: name 'model' is not defined
# Error: name 'model' is not defined
# Error: name 'model' is not defined
# Error: name 'model' is not defined
# Error: name 'model' is not defined
# Error: name 'model' is not defined
# Error: name 'model' is not defined
# Error: name 'model' is not defined
# Error: name 'model' is not defined
# Error: name 'model' is not defined
# Error: name 'model' is not defined
# Error: name 'model' is not defined
# Error: name 'model' is not defined
# Error: name 'model' is not defined
# Error: name 'model' is not defined
# Error: name 'model' is not defined
# Error: name 'model' is not defined
# Error: name 'model' is not defined
# Error: name 'model' is not defined
# Error: name 'model' is not defined
# Error: name 'model' is not defined
# Error: name 'model' is not defined
# Error: name 'model' is not defined
# Error: name 'model' is not defined
# Error: name 'model' is not defined
# Error: name 'model' is not defined
# Error: name 'model' is not defined
# Error: name 'model' is not defined
# Error: name 'model' is not defined
# Error: name 'model' is not defined
# Error: name 'model' is not defined
# Error: name 'model' is not defined
# Error: name 'model' is not defined
# Error: name 'model' is not defined
# Error: name 'model' is not defined
# Error: name 'model' is not defined
# Error: name 'model' is not defined
# Error: name 'model' is not defined
# Error: name 'model' is not defined
# Error: name 'model' is not defined
# Error: name 'model' is not defined
# Error: name 'model' is not defined
# Error: name 'model' is not defined
# Error: name 'model' is not defined
# Error: name 'model' is not defined
# Error: name 'model' is not defined
# Error: name 'model' is not defined
# Error: name 'model' is not defined
# Error: name 'model' is not defined
# Error: name 'model' is not defined
# Error: name 'model' is not defined
# Error: name 'model' is not defined
# Error: name 'model' is not defined
# Error: name 'model' is not defined
# Error: name 'model' is not defined
# Error: name 'model' is not defined

# %%
import pandas as pd
import mediapipe as mp
import numpy as np
import cv2
import pickle

# %%
mp_drawing = mp.solutions.drawing_utils # Drawing helpers
mp_holistic = mp.solutions.holistic # Mediapipe Solutions

mp_drawing_styles = mp.solutions.drawing_styles
mp_hands = mp.solutions.hands

# %%
with open('body_language.pkl', 'rb') as f:
    model = pickle.load(f)

# %%
model
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('randomforestclassifier', RandomForestClassifier())])

# %%
import warnings
warnings.filterwarnings("ignore", message="X does not have valid feature names")

cap = cv2.VideoCapture(0)

# Initiate holistic model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic, \
     mp_hands.Hands(min_detection_confidence=0.5, min_tracking_confidence=0.5) as hands:
    
    
    while cap.isOpened():
        ret, frame = cap.read()
        frame = cv2.resize(frame,(800,590))

        if not ret:
            print("Unable to capture frame")
            break

        # Recolor feed
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False

        # Make detections
        results_holistic = holistic.process(image)
        results_hands = hands.process(image)

        # Recolor image back to BGR for rendering
        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

        mp_drawing.draw_landmarks(image, results_holistic.face_landmarks, mp_holistic.FACEMESH_TESSELATION,
                                  mp_drawing.DrawingSpec(color=(80, 110, 10), thickness=1, circle_radius=1),
                                  mp_drawing.DrawingSpec(color=(80, 256, 121), thickness=1, circle_radius=1))

        # Draw pose landmarks
        mp_drawing.draw_landmarks(image, results_holistic.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                                  mp_drawing.DrawingSpec(color=(245, 117, 66), thickness=2, circle_radius=4),
                                  mp_drawing.DrawingSpec(color=(245, 66, 230), thickness=2, circle_radius=2))

        # Draw hand landmarks
        if results_hands.multi_hand_landmarks:
            for hand_landmarks in results_hands.multi_hand_landmarks:
                mp_drawing.draw_landmarks(image, hand_landmarks, mp_hands.HAND_CONNECTIONS,
                                          mp_drawing_styles.get_default_hand_landmarks_style(),
                                          mp_drawing_styles.get_default_hand_connections_style())
                

        try:
            # Extract pose landmarks
            pose_landmarks = results_holistic.pose_landmarks.landmark
            pose_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in pose_landmarks]).flatten())

            # Extract face landmarks
            face_landmarks = results_holistic.face_landmarks.landmark
            face_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in face_landmarks]).flatten())

            # Extract hand landmarks
            hand_landmarks = []
            if results_hands.multi_hand_landmarks:
                for hand_landmark in results_hands.multi_hand_landmarks:
                    hand_landmarks.extend(list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in hand_landmark.landmark]).flatten()))

            # Concatenate rows
            row = pose_row + face_row + hand_landmarks

            # Append class name
            # row.insert(0, class_name)

            # with open('coords.csv', mode='a', newline='') as f:
            #     csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
            #     csv_writer.writerow(row)

            X = pd.DataFrame([row])
            body_language_class = model.predict(X)[0]
            body_language_prob = model.predict_proba(X)[0]
            print(body_language_class, body_language_prob)

            # Grab ear coords
            coords = tuple(np.multiply(
                            np.array(
                                (results_holistic.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].x, 
                                 results_holistic.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].y))
                        , [640,480]).astype(int))
            

            cv2.rectangle(image, 
                          (coords[0], coords[1]+5), 
                          (coords[0]+len(body_language_class)*20, coords[1]-30), 
                          (245, 117, 16), -1)
            cv2.putText(image, body_language_class, coords, 
                        cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            
            # Get status box
            cv2.rectangle(image, (0,0), (250, 60), (245, 117, 16), -1)
            
            # Display Class
            cv2.putText(image, 'CLASS'
                        , (95,12), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 1, cv2.LINE_AA)
            cv2.putText(image, body_language_class.split(' ')[0]
                        , (90,40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            
            # Display Probability
            cv2.putText(image, 'PROB'
                        , (15,12), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 1, cv2.LINE_AA)
            cv2.putText(image, str(round(body_language_prob[np.argmax(body_language_prob)],2))
                        , (10,40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)

        except Exception as e:
            print(f"Error: {e}")
                
        
        cv2.imshow('Webcam Feed', image)

        # Break the loop if 'q' is pressed
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

# Release the webcam and close all windows
cap.release()
cv2.destroyAllWindows()
# Out:
# Error: 'NoneType' object has no attribute 'landmark'
# Error: 'NoneType' object has no attribute 'landmark'
# Error: 'NoneType' object has no attribute 'landmark'
# Error: X has 2004 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2004 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2004 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2004 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2004 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2004 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2004 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2004 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2004 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2004 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2004 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2004 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2004 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2004 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2004 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2004 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2004 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2004 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2004 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2004 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2004 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2004 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2004 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2004 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2004 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2004 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2004 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2004 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2004 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2004 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2004 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2004 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2004 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2004 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2004 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2004 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2004 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2004 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2004 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2004 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2004 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2004 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2004 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2004 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2004 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2004 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2004 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2004 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2004 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2004 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2004 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2004 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2004 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2004 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2004 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2004 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2004 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2004 features, but StandardScaler is expecting 2088 features as input.
# Wrong_Hand [0.23 0.16 0.61]
# Wrong_Hand [0.24 0.15 0.61]
# Error: X has 2172 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2172 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2172 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2172 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2172 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2172 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2172 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2172 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2172 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2172 features, but StandardScaler is expecting 2088 features as input.
# Wrong_Hand [0.12 0.08 0.8 ]
# Wrong_Hand [0.08 0.12 0.8 ]
# Wrong_Hand [0.09 0.09 0.82]
# Error: X has 2172 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2172 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2172 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2172 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2172 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2172 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2172 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2172 features, but StandardScaler is expecting 2088 features as input.
# Wrong_Hand [0.32 0.09 0.59]
# Error: X has 2172 features, but StandardScaler is expecting 2088 features as input.
# Wrong_Hand [0.07 0.08 0.85]
# Error: 'NoneType' object has no attribute 'landmark'
# Error: 'NoneType' object has no attribute 'landmark'
# Error: 'NoneType' object has no attribute 'landmark'
# Error: 'NoneType' object has no attribute 'landmark'
# Wrong_Hand [0.22 0.1  0.68]
# Wrong_Hand [0.24 0.11 0.65]
# Wrong_Hand [0.29 0.09 0.62]
# Wrong_Hand [0.32 0.06 0.62]
# Error: X has 2172 features, but StandardScaler is expecting 2088 features as input.
# Error: 'NoneType' object has no attribute 'landmark'
# Error: 'NoneType' object has no attribute 'landmark'
# Error: 'NoneType' object has no attribute 'landmark'
# Error: 'NoneType' object has no attribute 'landmark'
# Error: 'NoneType' object has no attribute 'landmark'
# Error: 'NoneType' object has no attribute 'landmark'
# Error: 'NoneType' object has no attribute 'landmark'
# Error: X has 2004 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2004 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2004 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2004 features, but StandardScaler is expecting 2088 features as input.
# Wrong_Hand [0.07 0.09 0.84]
# Wrong_Hand [0.27 0.11 0.62]
# Wrong_Hand [0.3  0.18 0.52]
# Wrong_Hand [0.34 0.13 0.53]
# Wrong_Hand [0.36 0.12 0.52]
# Wrong_Hand [0.37 0.1  0.53]
# Wrong_Hand [0.38 0.1  0.52]
# Wrong_Hand [0.38 0.1  0.52]
# Wrong_Hand [0.4  0.08 0.52]
# Wrong_Hand [0.38 0.1  0.52]
# Wrong_Hand [0.38 0.1  0.52]
# Wrong_Hand [0.39 0.1  0.51]
# Wrong_Hand [0.37 0.1  0.53]
# Wrong_Hand [0.36 0.1  0.54]
# Wrong_Hand [0.36 0.1  0.54]
# Wrong_Hand [0.36 0.1  0.54]
# Error: X has 2172 features, but StandardScaler is expecting 2088 features as input.
# Wrong_Hand [0.37 0.11 0.52]
# Error: X has 2172 features, but StandardScaler is expecting 2088 features as input.
# Wrong_Hand [0.35 0.11 0.54]
# Error: X has 2172 features, but StandardScaler is expecting 2088 features as input.
# Wrong_Hand [0.35 0.11 0.54]
# Wrong_Hand [0.34 0.09 0.57]
# Error: X has 2172 features, but StandardScaler is expecting 2088 features as input.
# Wrong_Hand [0.34 0.11 0.55]
# Error: X has 2172 features, but StandardScaler is expecting 2088 features as input.
# Wrong_Hand [0.35 0.1  0.55]
# Error: X has 2172 features, but StandardScaler is expecting 2088 features as input.
# Error: 'NoneType' object has no attribute 'landmark'
# Error: 'NoneType' object has no attribute 'landmark'
# Error: 'NoneType' object has no attribute 'landmark'
# Error: 'NoneType' object has no attribute 'landmark'
# Wrong_Hand [0.12 0.1  0.78]
# Wrong_Hand [0.19 0.12 0.69]
# Wrong_Hand [0.34 0.09 0.57]
# Error: X has 2004 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2004 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2004 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2004 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2004 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2004 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2004 features, but StandardScaler is expecting 2088 features as input.
# No_Salute [0.3  0.51 0.19]
# No_Salute [0.28 0.53 0.19]
# No_Salute [0.33 0.46 0.21]
# No_Salute [0.3  0.49 0.21]
# No_Salute [0.32 0.51 0.17]
# No_Salute [0.36 0.51 0.13]
# No_Salute [0.36 0.51 0.13]
# No_Salute [0.29 0.6  0.11]
# No_Salute [0.33 0.57 0.1 ]
# No_Salute [0.32 0.59 0.09]
# No_Salute [0.33 0.58 0.09]
# No_Salute [0.32 0.56 0.12]
# No_Salute [0.29 0.62 0.09]
# No_Salute [0.29 0.61 0.1 ]
# No_Salute [0.33 0.57 0.1 ]
# No_Salute [0.17 0.74 0.09]
# No_Salute [0.32 0.58 0.1 ]
# No_Salute [0.32 0.58 0.1 ]
# No_Salute [0.33 0.59 0.08]
# No_Salute [0.23 0.68 0.09]
# No_Salute [0.19 0.73 0.08]
# No_Salute [0.08 0.82 0.1 ]
# No_Salute [0.08 0.84 0.08]
# No_Salute [0.21 0.7  0.09]
# No_Salute [0.22 0.7  0.08]
# No_Salute [0.25 0.68 0.07]
# Error: 'NoneType' object has no attribute 'landmark'
# Error: 'NoneType' object has no attribute 'landmark'
# Error: 'NoneType' object has no attribute 'landmark'
# Error: 'NoneType' object has no attribute 'landmark'
# Error: 'NoneType' object has no attribute 'landmark'
# No_Salute [0.41 0.5  0.09]
# No_Salute [0.37 0.52 0.11]
# No_Salute [0.37 0.52 0.11]
# Error: X has 2004 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2004 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2004 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2004 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2004 features, but StandardScaler is expecting 2088 features as input.
# No_Salute [0.42 0.49 0.09]
# No_Salute [0.37 0.55 0.08]
# No_Salute [0.37 0.56 0.07]
# No_Salute [0.37 0.56 0.07]
# No_Salute [0.35 0.6  0.05]
# No_Salute [0.35 0.55 0.1 ]
# No_Salute [0.32 0.56 0.12]
# Error: X has 2172 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2172 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2172 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2172 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2172 features, but StandardScaler is expecting 2088 features as input.
# No_Salute [0.33 0.55 0.12]
# No_Salute [0.36 0.56 0.08]
# No_Salute [0.37 0.58 0.05]
# No_Salute [0.38 0.57 0.05]
# No_Salute [0.36 0.57 0.07]
# No_Salute [0.36 0.6  0.04]
# No_Salute [0.36 0.55 0.09]
# No_Salute [0.36 0.57 0.07]
# No_Salute [0.38 0.59 0.03]
# No_Salute [0.38 0.61 0.01]
# No_Salute [0.39 0.6  0.01]
# No_Salute [0.38 0.61 0.01]
# No_Salute [0.41 0.59 0.  ]
# Best_Salute [0.57 0.43 0.  ]
# Best_Salute [0.67 0.33 0.  ]
# Best_Salute [0.66 0.34 0.  ]
# Best_Salute [0.64 0.35 0.01]
# Best_Salute [0.65 0.34 0.01]
# Best_Salute [0.63 0.36 0.01]
# Best_Salute [0.67 0.33 0.  ]
# Best_Salute [0.71 0.26 0.03]
# Best_Salute [0.73 0.26 0.01]
# Best_Salute [0.73 0.24 0.03]
# Best_Salute [0.74 0.23 0.03]
# Best_Salute [0.74 0.25 0.01]
# Best_Salute [0.74 0.25 0.01]
# Best_Salute [0.73 0.26 0.01]
# Best_Salute [0.73 0.26 0.01]
# Best_Salute [0.76 0.23 0.01]
# Best_Salute [0.73 0.26 0.01]
# Best_Salute [0.74 0.25 0.01]
# Best_Salute [0.73 0.26 0.01]
# Best_Salute [0.74 0.25 0.01]
# Best_Salute [0.72 0.23 0.05]
# Best_Salute [0.71 0.24 0.05]
# Best_Salute [0.64 0.22 0.14]
# Best_Salute [0.64 0.23 0.13]
# Best_Salute [0.63 0.24 0.13]
# Best_Salute [0.57 0.28 0.15]
# Best_Salute [0.63 0.25 0.12]
# Best_Salute [0.58 0.27 0.15]
# Best_Salute [0.58 0.27 0.15]
# Best_Salute [0.68 0.26 0.06]
# Best_Salute [0.69 0.29 0.02]
# Best_Salute [0.71 0.27 0.02]
# Best_Salute [0.7  0.28 0.02]
# Best_Salute [0.72 0.25 0.03]
# Best_Salute [0.72 0.23 0.05]
# Best_Salute [0.71 0.25 0.04]
# Best_Salute [0.74 0.23 0.03]
# Best_Salute [0.72 0.22 0.06]
# Best_Salute [0.71 0.23 0.06]
# Best_Salute [0.71 0.23 0.06]
# Best_Salute [0.71 0.23 0.06]
# Best_Salute [0.7  0.24 0.06]
# Error: X has 2004 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2004 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2004 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2004 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2004 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2004 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2004 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2004 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2004 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2004 features, but StandardScaler is expecting 2088 features as input.

# %%
tuple(np.multiply(np.array((results_holistic.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].x, 
                            results_holistic.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].y)), [640,480]).astype(int))
# Out:
# (399, 203)

# %%
import cv2
import mediapipe as mp

# Initialize MediaPipe Hands model
mp_hands = mp.solutions.hands
hands = mp_hands.Hands(min_detection_confidence=0.5, min_tracking_confidence=0.5)

# Initialize webcam
cap = cv2.VideoCapture(0)

while cap.isOpened():
    ret, frame = cap.read()
    frame = cv2.resize(frame,(800,600))

    if not ret:
        print("Unable to capture frame")
        break

    # Convert frame to RGB
    image_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

    # Process hand landmarks detection
    results = hands.process(image_rgb)

    # Draw landmarks if hands are detected
    if results.multi_hand_landmarks:
        for hand_landmarks in results.multi_hand_landmarks:
            # Draw hand landmarks
            mp_drawing.draw_landmarks(
                frame, hand_landmarks, mp_hands.HAND_CONNECTIONS)

    # Display the frame
    cv2.imshow('Hand Landmarks Detection', frame)

    # Break the loop when 'q' is pressed
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the webcam and close all windows
cap.release()
cv2.destroyAllWindows()

# %%
import warnings
warnings.filterwarnings("ignore", message="X does not have valid feature names")

cap = cv2.VideoCapture('salute2.mp4')  # Replace with your video file path

# Initiate holistic model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic, \
     mp_hands.Hands(min_detection_confidence=0.5, min_tracking_confidence=0.5) as hands:
    
    while cap.isOpened():
        ret, frame = cap.read()
        frame = cv2.resize(frame, (800, 850))

        if not ret:
            print("Unable to capture frame or end of video")
            break

        # Recolor feed
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False

        # Make detections
        results_holistic = holistic.process(image)
        results_hands = hands.process(image)

        # Recolor image back to BGR for rendering
        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

        mp_drawing.draw_landmarks(image, results_holistic.face_landmarks, mp_holistic.FACEMESH_TESSELATION,
                                  mp_drawing.DrawingSpec(color=(80, 110, 10), thickness=1, circle_radius=1),
                                  mp_drawing.DrawingSpec(color=(80, 256, 121), thickness=1, circle_radius=1))

        # Draw pose landmarks
        mp_drawing.draw_landmarks(image, results_holistic.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                                  mp_drawing.DrawingSpec(color=(245, 117, 66), thickness=2, circle_radius=4),
                                  mp_drawing.DrawingSpec(color=(245, 66, 230), thickness=2, circle_radius=2))

        # Draw hand landmarks
        if results_hands.multi_hand_landmarks:
            for hand_landmarks in results_hands.multi_hand_landmarks:
                mp_drawing.draw_landmarks(image, hand_landmarks, mp_hands.HAND_CONNECTIONS,
                                          mp_drawing_styles.get_default_hand_landmarks_style(),
                                          mp_drawing_styles.get_default_hand_connections_style())
                

        try:
            # Extract pose landmarks
            pose_landmarks = results_holistic.pose_landmarks.landmark
            pose_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in pose_landmarks]).flatten())

            # Extract face landmarks
            face_landmarks = results_holistic.face_landmarks.landmark
            face_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in face_landmarks]).flatten())

            # Extract hand landmarks
            hand_landmarks = []
            if results_hands.multi_hand_landmarks:
                for hand_landmark in results_hands.multi_hand_landmarks:
                    hand_landmarks.extend(list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in hand_landmark.landmark]).flatten()))

            # Concatenate rows
            row = pose_row + face_row + hand_landmarks

            X = pd.DataFrame([row])
            body_language_class = model.predict(X)[0]
            body_language_prob = model.predict_proba(X)[0]
            print(body_language_class, body_language_prob)

            # Grab ear coords
            coords = tuple(np.multiply(
                            np.array(
                                (results_holistic.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].x, 
                                 results_holistic.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].y))
                        , [800, 590]).astype(int))
            

            cv2.rectangle(image, 
                          (coords[0], coords[1]+5), 
                          (coords[0]+len(body_language_class)*20, coords[1]-30), 
                          (245, 117, 16), -1)
            cv2.putText(image, body_language_class, coords, 
                        cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            
            # Get status box
            cv2.rectangle(image, (0,0), (250, 60), (245, 117, 16), -1)
            
            # Display Class
            cv2.putText(image, 'CLASS'
                        , (95,12), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 1, cv2.LINE_AA)
            cv2.putText(image, body_language_class.split(' ')[0]
                        , (90,40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
            
            # Display Probability
            cv2.putText(image, 'PROB'
                        , (15,12), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 1, cv2.LINE_AA)
            cv2.putText(image, str(round(body_language_prob[np.argmax(body_language_prob)],2))
                        , (10,40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)

        except Exception as e:
            print(f"Error: {e}")
                
        
        cv2.imshow('Video Feed', image)

        # Break the loop if 'q' is pressed
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

# Release the video capture and close all windows
cap.release()
cv2.destroyAllWindows()
# Out:
# Wrong_Hand [0.18 0.35 0.47]
# Wrong_Hand [0.17 0.36 0.47]
# Wrong_Hand [0.17 0.38 0.45]
# Wrong_Hand [0.17 0.36 0.47]
# Wrong_Hand [0.17 0.36 0.47]
# Error: X has 2172 features, but StandardScaler is expecting 2088 features as input.
# Wrong_Hand [0.16 0.38 0.46]
# Wrong_Hand [0.16 0.38 0.46]
# Wrong_Hand [0.16 0.38 0.46]
# Wrong_Hand [0.16 0.39 0.45]
# Wrong_Hand [0.14 0.4  0.46]
# Wrong_Hand [0.16 0.39 0.45]
# Wrong_Hand [0.16 0.39 0.45]
# Wrong_Hand [0.16 0.38 0.46]
# Wrong_Hand [0.16 0.38 0.46]
# Wrong_Hand [0.15 0.39 0.46]
# Wrong_Hand [0.15 0.39 0.46]
# Error: X has 2172 features, but StandardScaler is expecting 2088 features as input.
# Wrong_Hand [0.15 0.37 0.48]
# Error: X has 2004 features, but StandardScaler is expecting 2088 features as input.
# Wrong_Hand [0.14 0.36 0.5 ]
# Wrong_Hand [0.14 0.34 0.52]
# Wrong_Hand [0.15 0.32 0.53]
# Wrong_Hand [0.15 0.32 0.53]
# Wrong_Hand [0.14 0.33 0.53]
# Wrong_Hand [0.14 0.33 0.53]
# Wrong_Hand [0.15 0.32 0.53]
# Wrong_Hand [0.15 0.33 0.52]
# Error: X has 2172 features, but StandardScaler is expecting 2088 features as input.
# Wrong_Hand [0.15 0.35 0.5 ]
# Error: X has 2172 features, but StandardScaler is expecting 2088 features as input.
# Wrong_Hand [0.14 0.33 0.53]
# Error: X has 2172 features, but StandardScaler is expecting 2088 features as input.
# Wrong_Hand [0.14 0.33 0.53]
# Error: X has 2172 features, but StandardScaler is expecting 2088 features as input.
# Wrong_Hand [0.14 0.33 0.53]
# Error: X has 2172 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2004 features, but StandardScaler is expecting 2088 features as input.
# Wrong_Hand [0.15 0.34 0.51]
# Wrong_Hand [0.15 0.34 0.51]
# Wrong_Hand [0.15 0.33 0.52]
# Wrong_Hand [0.15 0.32 0.53]
# Wrong_Hand [0.15 0.32 0.53]
# Error: X has 2172 features, but StandardScaler is expecting 2088 features as input.
# Wrong_Hand [0.15 0.32 0.53]
# Wrong_Hand [0.15 0.33 0.52]
# Error: X has 2172 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2004 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2004 features, but StandardScaler is expecting 2088 features as input.
# Wrong_Hand [0.15 0.35 0.5 ]
# Wrong_Hand [0.15 0.33 0.52]
# Wrong_Hand [0.13 0.31 0.56]
# Error: X has 2172 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2172 features, but StandardScaler is expecting 2088 features as input.
# Wrong_Hand [0.15 0.34 0.51]
# Error: X has 2172 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2004 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2172 features, but StandardScaler is expecting 2088 features as input.
# Wrong_Hand [0.17 0.37 0.46]
# Wrong_Hand [0.18 0.37 0.45]
# Wrong_Hand [0.14 0.41 0.45]
# Wrong_Hand [0.25 0.29 0.46]
# Wrong_Hand [0.25 0.28 0.47]
# Error: X has 2172 features, but StandardScaler is expecting 2088 features as input.
# Wrong_Hand [0.25 0.23 0.52]
# Wrong_Hand [0.22 0.24 0.54]
# Wrong_Hand [0.25 0.26 0.49]
# Wrong_Hand [0.23 0.28 0.49]
# Error: X has 2172 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2172 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2172 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2172 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2172 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2172 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2172 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2172 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2172 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2172 features, but StandardScaler is expecting 2088 features as input.
# No_Salute [0.34 0.41 0.25]
# Error: X has 2172 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2172 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2172 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2172 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2172 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2172 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2172 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2172 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2172 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2172 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2172 features, but StandardScaler is expecting 2088 features as input.
# No_Salute [0.3  0.46 0.24]
# No_Salute [0.28 0.44 0.28]
# No_Salute [0.29 0.46 0.25]
# No_Salute [0.28 0.45 0.27]
# Error: X has 2172 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2172 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2172 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2172 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2172 features, but StandardScaler is expecting 2088 features as input.
# No_Salute [0.3  0.43 0.27]
# No_Salute [0.3  0.41 0.29]
# No_Salute [0.3  0.41 0.29]
# No_Salute [0.33 0.42 0.25]
# No_Salute [0.34 0.42 0.24]
# No_Salute [0.33 0.41 0.26]
# No_Salute [0.35 0.41 0.24]
# No_Salute [0.34 0.41 0.25]
# No_Salute [0.33 0.42 0.25]
# No_Salute [0.32 0.43 0.25]
# No_Salute [0.32 0.43 0.25]
# No_Salute [0.32 0.43 0.25]
# No_Salute [0.32 0.43 0.25]
# No_Salute [0.32 0.43 0.25]
# No_Salute [0.31 0.44 0.25]
# Error: X has 2172 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2172 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2172 features, but StandardScaler is expecting 2088 features as input.
# Wrong_Hand [0.25 0.32 0.43]
# Error: X has 2256 features, but StandardScaler is expecting 2088 features as input.
# Wrong_Hand [0.16 0.4  0.44]
# Error: X has 2172 features, but StandardScaler is expecting 2088 features as input.
# Error: X has 2172 features, but StandardScaler is expecting 2088 features as input.

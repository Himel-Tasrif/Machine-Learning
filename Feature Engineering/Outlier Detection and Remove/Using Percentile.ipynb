# %% [markdown]
# # Basic About outlier

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("heights.csv")
df
# Out:
#        name  height
# 0     mohan     5.9
# 1     maria     5.2
# 2     sakib     5.1
# 3       tao     5.5
# 4     virat     4.9
# 5    khusbu     5.4
# 6    dmitry     6.2
# 7    selena     6.5
# 8      john     7.1
# 9     imran    14.5
# 10     jose     6.1
# 11  deepika     5.6
# 12   yoseph     1.2
# 13    binod     5.5

# %%
max_threshold = df['height'].quantile(0.95)
max_threshold
# Out:
# 9.689999999999998

# %%
df[df['height'] > max_threshold]
# Out:
#     name  height
# 9  imran    14.5

# %%
min_threshold = df['height'].quantile(0.05)
min_threshold
# Out:
# 3.6050000000000004

# %%
df[df['height'] < min_threshold]
# Out:
#       name  height
# 12  yoseph     1.2

# %%
df[(df['height'] < max_threshold) & (df['height'] > min_threshold)]
# Out:
#        name  height
# 0     mohan     5.9
# 1     maria     5.2
# 2     sakib     5.1
# 3       tao     5.5
# 4     virat     4.9
# 5    khusbu     5.4
# 6    dmitry     6.2
# 7    selena     6.5
# 8      john     7.1
# 10     jose     6.1
# 11  deepika     5.6
# 13    binod     5.5

# %% [markdown]
# # Move on into another file

# %%
hr = pd.read_csv("bhp.csv")
hr.head()
# Out:
#                    location       size  total_sqft  bath   price  bhk  \
# 0  Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1          Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2               Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3        Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                  Kothanur      2 BHK      1200.0   2.0   51.00    2
#
#    price_per_sqft
# 0            3699
# 1            4615
# 2            4305
# 3            6245
# 4            4250

# %%
hr.shape
# Out:
# (13200, 7)

# %%
hr.describe()
# Out:
#          total_sqft          bath         price           bhk  price_per_sqft
# count  13200.000000  13200.000000  13200.000000  13200.000000    1.320000e+04
# mean    1555.302783      2.691136    112.276178      2.800833    7.920337e+03
# std     1237.323445      1.338915    149.175995      1.292843    1.067272e+05
# min        1.000000      1.000000      8.000000      1.000000    2.670000e+02
# 25%     1100.000000      2.000000     50.000000      2.000000    4.267000e+03
# 50%     1275.000000      2.000000     71.850000      3.000000    5.438000e+03
# 75%     1672.000000      3.000000    120.000000      3.000000    7.317000e+03
# max    52272.000000     40.000000   3600.000000     43.000000    1.200000e+07

# %%
max_t = hr['price_per_sqft'].quantile(0.999)
max_t
# Out:
# 50959.36200000098

# %%
hr[hr['price_per_sqft'] >= max_t]
# Out:
#                 location       size  total_sqft  bath   price  bhk  \
# 345                other  3 Bedroom        11.0   3.0    74.0    3
# 1005               other      1 BHK        15.0   1.0    30.0    1
# 1106               other  5 Bedroom        24.0   2.0   150.0    5
# 4044      Sarjapur  Road  4 Bedroom         1.0   4.0   120.0    4
# 4924               other      7 BHK         5.0   7.0   115.0    7
# 5911         Mysore Road  1 Bedroom        45.0   1.0    23.0    1
# 6356        Bommenahalli  4 Bedroom      2940.0   3.0  2250.0    4
# 7012               other      1 BHK       650.0   1.0   500.0    1
# 7575               other      1 BHK       425.0   1.0   750.0    1
# 7799               other      4 BHK      2000.0   3.0  1063.0    4
# 8307   Bannerghatta Road      5 BHK      2500.0   4.0  1400.0    5
# 9436        Indira Nagar  4 Bedroom      2400.0   5.0  1250.0    4
# 11447         Whitefield  4 Bedroom        60.0   4.0   218.0    4
# ...

# %%
min_t = hr['price_per_sqft'].quantile(0.004)
min_t
# Out:
# 2252.388

# %%
hr[hr['price_per_sqft'] < min_t]
# Out:
#                           location       size  total_sqft  bath   price  bhk  \
# 130                Electronic City      2 BHK       880.0   1.0   16.50    2
# 361                     Chandapura      1 BHK       530.0   1.0   11.66    1
# 509         Banashankari Stage III  4 Bedroom      8500.0   4.0  145.00    4
# 665                      Yelahanka      3 BHK     35000.0   3.0  130.00    3
# 757                       Sarjapur  5 Bedroom      4360.0   4.0   90.00    5
# 798                          other  4 Bedroom     10961.0   4.0   80.00    4
# 982                  Chikkabanavar  1 Bedroom      1200.0   1.0   20.00    1
# 1363                    Chandapura      2 BHK       850.0   1.0   18.50    2
# 1503                    Chandapura      2 BHK      1201.0   2.0   27.00    2
# 1867                         other  3 Bedroom     52272.0   2.0  140.00    3
# 2375            Yelahanka New Town      1 BHK       960.0   2.0   18.00    1
# ...

# %%
hr1 = hr[(hr['price_per_sqft'] > min_t) & (hr['price_per_sqft'] <= max_t)]

# %%
hr1.shape
# Out:
# (13133, 7)

# %%
hr1
# Out:
#                        location       size  total_sqft  bath   price  bhk  \
# 0      Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1              Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2                   Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3            Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                      Kothanur      2 BHK      1200.0   2.0   51.00    2
# ...                         ...        ...         ...   ...     ...  ...
# 13195                Whitefield  5 Bedroom      3453.0   4.0  231.00    5
# 13196                     other      4 BHK      3600.0   5.0  400.00    4
# 13197     Raja Rajeshwari Nagar      2 BHK      1141.0   2.0   60.00    2
# 13198           Padmanabhanagar      4 BHK      4689.0   4.0  488.00    4
# 13199              Doddathoguru      1 BHK       550.0   1.0   17.00    1
#
#        price_per_sqft
# 0                3699
# 1                4615
# ...
